# %% [markdown]
# # SmartHire — Job Clustering
# K-Means clustering with silhouette score and a 2D TruncatedSVD visualization. Topic modeling is optional in the brief.

# %%
import sys
sys.path.append("../src")
import clustering
clustering.run()
# Out:
# ...
# SMART HIRE - JOB CLUSTERING
# ...
#
# Dataset Shape: (21851, 11)
# TF-IDF Shape: (21851, 5000)
#
# ...
# CLUSTERING RESULTS
# ...
# Number of Clusters: 5
# Silhouette Score: 0.0371
#
# Cluster Distribution:
# cluster
# 0    9095
# 1    2843
# 2    7678
# 3    1647
# 4     588
# Name: count, dtype: int64
#                                                 company   experience  \
# 0                                      mm media pvt ltd    0 - 1 yrs
# 1                                    find live infotech    0 - 0 yrs
# 2                   softtech career infosystem pvt. ltd    4 - 8 yrs
# 3                                onboard hrservices llp  11 - 15 yrs
# 4            spire technologies and solutions pvt. ltd.    6 - 8 yrs
# ...                                                 ...          ...
# 21846       morgan stanley advantage services pvt. ltd.   9 - 13 yrs
# 21847  careernet technologies pvt ltd hiring for client    3 - 5 yrs
# ...
